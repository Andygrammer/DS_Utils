# %% [markdown]
# # Code Blocks for Exploratory Data Analysis (EDA)

# %% [markdown]
# **Source (all credits to):** *Susan Maina*

# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# # 2. Prepare Data

# %%
# Load the data
data = pd.read_csv('../datasets/melb_data.csv')
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# # 3. EDA - Shape Exploration

# %%
# 1. #rows vs. #columns
data.shape
# Out:
# (13580, 21)

# %%
# 2. data types
data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
# 3. display a few rows
data.head()
data.tail()
data.sample(5)
# Out:
#                Suburb          Address  Rooms Type      Price Method  \
# 11858        Werribee  3 Parramatta Rd      3    h   452000.0     SP
# 5361         Richmond       6 Brady St      3    h  1275000.0      S
# 6802   Brunswick East     192 Blyth St      3    h  1600000.0      S
# 9818         Bundoora     74 Arthur St      3    h   796000.0      S
# 2785        Glen Iris    22 Aintree Rd      4    h  1800000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 11858    Biggin  22/07/2017      14.7    3030.0  ...       1.0  3.0     567.0
# 5361     Biggin  18/03/2017       2.6    3121.0  ...       2.0  1.0     132.0
# 6802     Jellis  27/11/2016       4.5    3057.0  ...       1.0  2.0     812.0
# 9818      Barry  24/06/2017      12.1    3083.0  ...       2.0  2.0     534.0
# 2785   Marshall  12/11/2016       9.2    3146.0  ...       3.0  2.0     743.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
# 4. plot each numeric feature ----- *********userful to detect outliers*********
data.hist(figsize=(14,14), xrot=45)
plt.show()

# %%
# 5. summary statistics of the numerical features
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# 6. summary statistics of the categorical features
data.describe(include='object')
# Out:
#            Suburb        Address   Type Method SellerG        Date  \
# count       13580          13580  13580  13580   13580       13580
# unique        314          13378      3      5     268          58
# top     Reservoir  53 William St      h      S  Nelson  27/05/2017
# freq          359              3   9449   9022    1565         473
#
#        CouncilArea             Regionname
# count        12211                  13580
# unique          33                      8
# top       Moreland  Southern Metropolitan
# freq          1163                   4695

# %%
# 7. plot each categorical feature ----- ******userful to detect sparse classes and mistakes in labeling******
for column in data.select_dtypes(include='object'):
    if data[column].nunique() < 10:     # 10 or fewer classes
        sns.countplot(y=column, data=data)
        plt.show()

# %%
# 8. segment the target variable by categorical features  

# *** useful to determine which classes most affect the target variables ***

for column in data.select_dtypes(include='object'):
    if data[column].nunique() < 10:
        sns.boxplot(y=column, x='Price', data=data)
        plt.show()

# %%
# 9. group numeric features by each categorical feature
for column in data.select_dtypes(include='object'):
    if data[column].nunique() < 10: # for only the 3 categorical features with less than 10 classes
        display(data.groupby(column).mean())
# Out:
#          Rooms         Price   Distance     Postcode  Bedroom2  Bathroom  \
# Type
# h     3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# t     2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# u     1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#            Car    Landsize  BuildingArea    YearBuilt  Lattitude  Longtitude  \
# Type
# h     1.771222  617.181924    176.866248  1954.081176 -37.803795  144.994700
# t     1.555655  279.606822    140.046323  1998.988189 -37.815782  144.996489
# u     1.128358  477.314219     80.737121  1980.016708 -37.823710  144.996363
#
#       Propertycount
# Type
# h       7259.025505
# t       7094.459605
# u       8199.280080
#            Rooms         Price   Distance     Postcode  Bedroom2  Bathroom  \
# Method
# PI      3.077366  1.133242e+06   9.482097  3106.742327  3.062660  1.714194
# S       2.941809  1.087327e+06  10.431523  3106.171359  2.914875  1.498781
# ...

# %%
# 10. correlations matrix for the different numerical features
"""""
A positive correlation means that as one feature increases the other one also increases, 
while a negative correlation means one feature increases as the other decreases. 
Correlations close to 0 indicate a weak relationship while closer to -1 or 1 signifies a strong relationship.
"""""
corrs = data.corr()
corrs
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
# 11. heatmap of the correlations
"""
The cmap=‘RdBu_r’ argument tells the heatmap what colour palette to use.
A high positive correlation appears as dark red and a high negative correlation as dark blue.
Closer to white signifies a weak relationship. Read this nice tutorial for other color palettes.
annot=True includes the values of the correlations in the boxes for easier reading and interpretation.
"""
plt.figure(figsize=(10,8))
sns.heatmap(corrs, cmap='RdBu_r', annot=True)
plt.show()
